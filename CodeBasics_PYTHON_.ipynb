# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohith0750/Ds-And-Ai-ml-From-Scrartch/blob/main/CodeBasics_PYTHON_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Variables In python
#It is a container to store the data

can="Soda"
print(can)
print(type(can))

pizza=100
print(pizza)
print(type(pizza))
toatal=2.05
print(type(toatal))

toatal>1
# Out:
# Soda
# <class 'str'>
# 100
# <class 'int'>
# <class 'float'>
# True

# %%
#Naming Conventions
#cannot use  the reseverd  keywords
#Cannot use special chat &^
#vatibale should begin with letter ot _

# %%
#Area of a triangle
base=10
height=7

area=(base*height)/2
print(area)
# Out:
# 35.0
